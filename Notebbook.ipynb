# %% [markdown]
# Столбцы Gt_corners и Rb_corners совпадают. Построил графики для оценки статистической значимости признаков для определения количества углов. Сравнил плотности распределения признаков для комнат с разным количеством углов. Графики сохранил по отдельности так как считаю, что они в дальнейшем могут использоваться по отдельности.

# %%
from statistic_plots import draw_plots
PATH = 'https://ai-process-sandy.s3.eu-west-1.amazonaws.com/purge/deviation.json'
plots = draw_plots(PATH)
# Out:
# Пути сохранения графиков:
# plots\mean.png
# plots\max.png
# plots\min.png
# plots\floor_mean.png
# plots\floor_max.png
# plots\floor_min.png
# plots\ceiling_mean.png
# plots\ceiling_max.png
# plots\ceiling_min.png

# %%
print(plots)
# Out:
# ['plots\\mean.png', 'plots\\max.png', 'plots\\min.png', 'plots\\floor_mean.png', 'plots\\floor_max.png', 'plots\\floor_min.png', 'plots\\ceiling_mean.png', 'plots\\ceiling_max.png', 'plots\\ceiling_min.png']
